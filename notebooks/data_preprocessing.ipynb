# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import logging

import warnings
warnings.filterwarnings('ignore')

# %%
# Get the absolute path to the parent directory
parent_dir = os.path.dirname(os.getcwd())

# Add the parent directory to sys.path\n
sys.path.append(parent_dir)
from src import handler, visualizer

# %%
# Set up logging
logging.basicConfig(filename='../logs/data_preprocessing.log', level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# # Data Gathering

# %%
# %load_ext kedro.ipython
# Out:
# [06/26/24 23:01:14] INFO     Registered line magic '%reload_kedro'                                   ]8;id=422450;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=257720;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=631999;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=479985;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py#60\60]8;;\
#                     INFO     Resolved project path as: /home/derbew/Documents/10a/fraud-detection.  ]8;id=726882;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=524964;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py#171\171]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [06/26/24 23:01:21] INFO     Kedro project fraud_detection                                          ]8;id=557357;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=578798;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=512256;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=75895;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py#142\142]8;;\
#                              'pipelines'
# [06/26/24 23:01:26] INFO     Registered line magic 'run_viz'                                        ]8;id=833388;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=264647;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/ipython/__init__.py#148\148]8;;\

# %%
fraud_df = catalog.load("fraud_data")
credit_df = catalog.load("credit_card_data")
ip_df = catalog.load("ip_country_data")
# Out:
# [06/26/24 23:01:30] INFO     Loading data from fraud_data (CSVDataset)...                       ]8;id=429951;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=447504;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# [06/26/24 23:01:31] INFO     Loading data from credit_card_data (CSVDataset)...                 ]8;id=590561;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=230201;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# [06/26/24 23:01:35] INFO     Loading data from ip_country_data (CSVDataset)...                  ]8;id=240517;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=935521;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/kedro/io/data_catalog.py#508\508]8;;\

# %% [markdown]
# # Data OverView

# %%
fraud_df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
credit_df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
ip_df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %%
# create instances
df1 = handler.Handler(fraud_df)
df2 = handler.Handler(credit_df)
df3 = handler.Handler(ip_df)

# %%
# data overview fraud data
df1.data_overview()
# Out:
# Number of rows: 151112
# Number of columns: 11
#
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  object
#  2   purchase_time   151112 non-null  object
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.7+ MB
# None

# %%
# data overview credit data
df2.data_overview()
# Out:
# Number of rows: 284807
# Number of columns: 31
#
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB
# None

# %%
# data overview ip data
df3.data_overview()
# Out:
# Number of rows: 138846
# Number of columns: 3
#
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138846 entries, 0 to 138845
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   lower_bound_ip_address  138846 non-null  float64
#  1   upper_bound_ip_address  138846 non-null  int64
#  2   country                 138846 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.2+ MB
# None

# %% [markdown]
# # Data Cleaning
# - Handling missing values
# - Handling duplicate values
# - Handling outliers
# - Handling erroneous datatype

# %% [markdown]
# ## 1. Handling Missing Values
# Handling missing values is important step in data cleaning. Missing values can be represented as NaN (Not a Number) or empty strings. I use the `isnull()` function to identify missing values and the `dropna()` function to remove rows with missing values.

# %%
# checking missing values
df1.calculate_missing_percentage()
# Out:
#                 Missing Values Percentage Missing
# user_id                      0              0.00%
# signup_time                  0              0.00%
# purchase_time                0              0.00%
# purchase_value               0              0.00%
# device_id                    0              0.00%
# source                       0              0.00%
# browser                      0              0.00%
# sex                          0              0.00%
# age                          0              0.00%
# ip_address                   0              0.00%
# class                        0              0.00%

# %%
# checking missing values
df2.calculate_missing_percentage()
# Out:
#         Missing Values Percentage Missing
# Time                 0              0.00%
# V1                   0              0.00%
# V2                   0              0.00%
# V3                   0              0.00%
# V4                   0              0.00%
# V5                   0              0.00%
# V6                   0              0.00%
# V7                   0              0.00%
# V8                   0              0.00%
# V9                   0              0.00%
# V10                  0              0.00%
# V11                  0              0.00%
# V12                  0              0.00%
# V13                  0              0.00%
# V14                  0              0.00%
# V15                  0              0.00%
# V16                  0              0.00%
# V17                  0              0.00%
# V18                  0              0.00%
# V19                  0              0.00%
# V20                  0              0.00%
# V21                  0              0.00%
# V22                  0              0.00%
# V23                  0              0.00%
# V24                  0              0.00%
# V25                  0              0.00%
# V26                  0              0.00%
# V27                  0              0.00%
# V28                  0              0.00%
# Amount               0              0.00%
# Class                0              0.00%

# %%
# checking missing values
df3.calculate_missing_percentage()
# Out:
#                         Missing Values Percentage Missing
# lower_bound_ip_address               0              0.00%
# upper_bound_ip_address               0              0.00%
# country                              0              0.00%

# %% [markdown]
# ## 2. Handling Duplicate Values
# Handling duplicate values involves identifying and removing duplicate rows from the DataFrame. I use the `duplicated()` function to identify duplicate rows and the `drop_duplicates()` function to remove them.

# %%
# checking duplicate values
df1.check_duplicate()
# Out:
# Duplicated values:
# 0 duplicated rows

# %%
# checking duplicate values
df2.check_duplicate()
# Out:
# Duplicated values:
# 1081 duplicated rows

# %% [markdown]
# There is `1081` duplicated values in the credit card data.

# %%
# checking duplicate values
df3.check_duplicate()
# Out:
# Duplicated values:
# 0 duplicated rows

# %%
# drop duplicated value
credit_df.drop_duplicates(inplace=True)

# %%
df2.check_duplicate()
# Out:
# Duplicated values:
# 0 duplicated rows

# %% [markdown]
# ## 3. Handling outliers
# Handling outliers is a crucial step in data cleaning and preprocessing. Here are the key steps to handle outliers effectively:
# #### Identifying Outliers
# The first step is to identify the presence of outliers in my dataset. I Use box plots.

# %%
cols = ['purchase_value', "age"]
for col in cols:
    visualizer.plot_boxplot(fraud_df, col)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>

# %%
# checking outlires in the credit card data
credit_cols = ["Time", "Amount"]
for col in credit_cols:
    visualizer.plot_boxplot(credit_df, col)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>

# %% [markdown]
# ### Removing Outliers

# %%
for col in cols:
    df1.remove_iqr_outliers(col)

# %%
for col in cols:
    visualizer.plot_boxplot(fraud_df, col)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>

# %%
# Removing outliers from credit card data
df2.remove_iqr_outliers("Amount")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053     NaN
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752     NaN
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458     NaN
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649     NaN
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [283726 rows x 31 columns]

# %%
visualizer.plot_boxplot(credit_df, "Amount")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>

# %% [markdown]
# ### 4. Handling erroneous data type

# %%
# Correct data types
fraud_df['signup_time'] = pd.to_datetime(fraud_df['signup_time'])
fraud_df['purchase_time'] = pd.to_datetime(fraud_df['purchase_time'])

# %%
fraud_df.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# user_id                    int64
# signup_time       datetime64[ns]
# purchase_time     datetime64[ns]
# purchase_value           float64
# device_id                 object
# source                    object
# browser                   object
# sex                       object
# age                      float64
# ip_address               float64
# class                      int64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
def feature_eng():
    # Transaction frequency and velocity
    fraud_df['transaction_count'] = fraud_df.groupby('user_id')['user_id'].transform('count')
    fraud_df['transaction_velocity'] = fraud_df['transaction_count'] / (fraud_df['purchase_time'] - fraud_df['signup_time']).dt.total_seconds()

# %%
feature_eng()
df1.create_date_features('purchase_time')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11            34.0
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54            16.0
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45            15.0
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50            44.0
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53            39.0
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47            43.0
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39            35.0
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47            40.0
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46            46.0
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53            20.0
#
#             device_id  source browser sex   age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M  39.0  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F  53.0  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M  53.0  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M  41.0  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M  45.0  4.155831e+08      0
# ...               ...     ...     ...  ..   ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M  28.0  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M  32.0  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F  26.0  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M  37.0  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M  38.0  4.103825e+09      0
#
#         transaction_count  transaction_velocity  hour_of_day  day day_of_week  \
# 0                       1          2.218927e-07            2   18    Saturday
# 1                       1          5.572893e-05            1    8      Monday
# 2                       1          1.000000e+00           18    1    Thursday
# 3                       1          2.032169e-06           13    4      Monday
# 4                       1          2.292810e-07           18    9   Wednesday
# ...                   ...                   ...          ...  ...         ...
# 151107                  1          1.900695e-07            0   29      Sunday
# 151108                  1          1.073802e-06           12   26     Tuesday
# 151109                  1          1.496644e-07            7   20   Wednesday
# 151110                  1          1.943212e-07            9    7      Monday
# 151111                  1          2.837288e-07            2   21     Tuesday
#
#             month  year
# 0           April  2015
# 1            June  2015
# 2         January  2015
# 3             May  2015
# 4       September  2015
# ...           ...   ...
# 151107      March  2015
# 151108        May  2015
# 151109        May  2015
# 151110  September  2015
# 151111       July  2015
#
# [151112 rows x 18 columns]

# %%
df1.drop_missing_values()
df1.calculate_missing_percentage()
# Out:
#                       Missing Values Percentage Missing
# user_id                            0              0.00%
# signup_time                        0              0.00%
# purchase_time                      0              0.00%
# purchase_value                     0              0.00%
# device_id                          0              0.00%
# source                             0              0.00%
# browser                            0              0.00%
# sex                                0              0.00%
# age                                0              0.00%
# ip_address                         0              0.00%
# class                              0              0.00%
# transaction_count                  0              0.00%
# transaction_velocity               0              0.00%
# hour_of_day                        0              0.00%
# day                                0              0.00%
# day_of_week                        0              0.00%
# month                              0              0.00%
# year                               0              0.00%

# %% [markdown]
# # Descriptive Statistics

# %%
# fraud dataset
num_cols, cat_cols = fraud_df.select_dtypes(exclude=['object']), fraud_df.select_dtypes(include=["object"])

# %%
num_cols.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              user_id                    signup_time  \
# count  149277.000000                         149277
# mean   200170.498161  2015-04-20 00:55:45.170983936
# min         2.000000            2015-01-01 00:00:42
# 25%    100623.000000            2015-02-18 09:38:17
# 50%    200001.000000            2015-04-19 04:07:25
# 75%    300038.000000            2015-06-18 15:44:13
# max    400000.000000            2015-08-18 04:40:29
# std    115368.377754                            NaN
#
#                        purchase_time  purchase_value            age  \
# count                         149277   149277.000000  149277.000000
# mean   2015-06-16 02:54:16.488086016       36.501651      33.001005
# min              2015-01-01 00:00:44        9.000000      18.000000
# 25%              2015-04-18 14:24:55       22.000000      27.000000
# 50%              2015-06-18 13:36:42       34.000000      32.000000
# 75%              2015-08-17 18:40:09       48.000000      39.000000
# max              2015-12-16 02:56:05       89.000000      57.000000
# std                              NaN       17.645555       8.409680
#
#          ip_address          class  transaction_count  transaction_velocity  \
# count  1.492770e+05  149277.000000           149277.0          1.492770e+05
# mean   2.152525e+09       0.093605                1.0          5.022976e-02
# min    5.209350e+04       0.000000                1.0          9.645088e-08
# 25%    1.086213e+09       0.000000                1.0          1.307958e-07
# 50%    2.155693e+09       0.000000                1.0          2.029967e-07
# 75%    3.243797e+09       0.000000                1.0          4.573210e-07
# max    4.294850e+09       1.000000                1.0          1.000000e+00
# std    1.248660e+09       0.291279                0.0          2.184172e-01
#
#          hour_of_day            day      year
# count  149277.000000  149277.000000  149277.0
# mean       11.520897      15.280505    2015.0
# min         0.000000       1.000000    2015.0
# 25%         6.000000       8.000000    2015.0
# 50%        12.000000      15.000000    2015.0
# 75%        17.000000      23.000000    2015.0
# max        23.000000      31.000000    2015.0
# std         6.912415       8.815217       0.0

# %%
cat_cols.describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             device_id  source browser     sex day_of_week   month
# count          149277  149277  149277  149277      149277  149277
# unique         136351       3       5       2           7      12
# top     KIPFSCNUGOLDP     SEO  Chrome       M      Sunday    July
# freq               20   59867   60724   87239       21738   19287

# %% [markdown]
# # Storing the Data

# %%
fraud_df.to_csv("../data/02_intermediate/preprocess_fraud_data.csv", index=False)
credit_df.to_csv("../data/02_intermediate/preprocess_credit_data.csv", index=False)

# %% [markdown]
# # Data Visualization
# Data visualization is a crucial aspect of data analysis, as it helps to effectively communicate insights and patterns in the data. Here's a brief overview of how data visualization can be applied in univariate, bivariate, and multivariate analysis.

# %% [markdown]
# ## Univariate analysis
# In univariate analysis, where only one variable is considered at a time. These visualizations help to understand the central tendency, spread, and shape of the distribution of a single variable.

# %% [markdown]
# ### Distribution of Numerical Features

# %%
num_cols.hist(figsize=(16, 20), bins=50, ylabelsize=8)
plt.title("Histogram of Features that has a num type")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1600x2000 with 12 Axes>

# %% [markdown]
# ## Distribution of Categorical Features

# %%
cat_col = ['source', 'browser', 'sex', 'day_of_week', 'month']
for col in cat_cols:
    visualizer.plot_count(fraud_df, col, hue_col='class')

# %% [markdown]
# ## Bivariate analysis and Multivariate analysis
#
# Multivariate analysis involves the study of three or more variables simultaneously. Visualizations for multivariate data can be more complex.
#
# Bivariate analysis examines the relationship between two variables.

# %%
num_cols.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['user_id', 'signup_time', 'purchase_time', 'purchase_value', 'age',
#        'ip_address', 'class', 'transaction_count', 'transaction_velocity',
#        'hour_of_day', 'day', 'year'],
#       dtype='object')

# %%
num_cols = ['user_id', 'signup_time', 'purchase_time', 'purchase_value', 'age',
       'ip_address', 'class', 'transaction_velocity', 'hour_of_day', 'day']
visualizer.correlation_matrix(fraud_df[num_cols])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 2 Axes>

# %%
visualizer.correlation_matrix(credit_df)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 2 Axes>

# %%
visualizer.plot_scatter(fraud_df, x_col='', y_col='age', hue_col='class')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>

# %%
# line plot of views over different time
cols = ['hour_of_day', "day", "day_of_week", "month"]
for col in cols:
    visualizer.plot_line(fraud_df, col, 'purchase_value')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>
# [06/26/24 23:22:27] INFO     Using categorical units to plot a list of strings that are all         ]8;id=462164;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=55067;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py#223\223]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
#                     INFO     Using categorical units to plot a list of strings that are all         ]8;id=924908;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=304933;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py#223\223]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>
# [06/26/24 23:22:29] INFO     Using categorical units to plot a list of strings that are all         ]8;id=124983;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=510534;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py#223\223]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
#                     INFO     Using categorical units to plot a list of strings that are all         ]8;id=803722;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=689317;file:///home/derbew/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/category.py#223\223]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x600 with 1 Axes>

# %%
visualizer.plot_bar(fraud_df, 'sex', 'purchase_value', 'class')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x1000 with 1 Axes>

# %%
visualizer.plot_bar(fraud_df, 'browser', 'purchase_value', 'class')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x1000 with 1 Axes>

# %%
visualizer.plot_bar(fraud_df, 'source', 'purchase_value', 'class')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x1000 with 1 Axes>
